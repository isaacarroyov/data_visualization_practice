# %% [markdown]
# # Visualizing Spotify 01. Part 1 : Principal Component Analysis

# %% [markdown]
# Esta notebook tiene el propósito de documentar todos los pasos necesarios para crear la visualización final

# %% [markdown]
# > This notebook has the porpouse to document all the necessary steps to create the final data visualization

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import altair as alt

# %%
# Remove later
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the data

# %%
# Change duration from ms to min
def convert_miliseconds(miliseconds, conversion = 'minutes'):
    if conversion == 'minutes':
        return miliseconds / 60000
    elif conversion == 'seconds':
        return miliseconds / 1000

# %%
# Rene Perez Joglar a.k.a Residente was the vocalist and 
# songwriter of Calle 13. In this project I consider both 
# artists the same person.
def find_residente_calle13(artist):
    condition_1 = artist == 'Calle 13'
    condition_2 = artist == 'Residente'
    if condition_1 or condition_2:
        return 'Residente/Calle 13'
    else: 
        return artist

# %%
df = pd.read_csv("https://raw.githubusercontent.com/isaacarroyov/spotify_anomalies_kmeans-lof/main/data/songs_atributtes_my_top_100_2016-2021.csv")

# Apply initial functions
df['artist'] = df['artist'].apply(find_residente_calle13)
df['duration_minutes'] = df['duration_ms'].apply(convert_miliseconds, args = ('minutes',))
df = df.drop(columns='duration_ms')

# Remove duplicated songs + artists
# For example: Growing Pains is duplicated and the artist is Alessia Cara (in both songs)
df = df.drop_duplicates(subset=['name', 'artist'], keep='first')
df = df.reset_index(drop=True)

print(f'This dataset has {df.shape[1]} attributes and {df.shape[0]} instances')

df.head()
# Out:
# This dataset has 18 attributes and 504 instances
#              name            artist  \
# 0      On My Wave  Keiynan Lonsdale
# 1          96,000     Anthony Ramos
# 2       Pessimist       Greta Isaac
# 3  Girl Next Door      Alessia Cara
# 4   Somebody Else      Alessia Cara
#
#                                                album                     URI  \
# 0                                        Rainbow Boy  01iaXaqUjZVsdLp2yF3OQ9
# 1  In The Heights (Original Motion Picture Soundt...  0CpE5SeQkHQPYiWX0psxf4
# 2                                          Pessimist  0IkBQt9vSLLwoX0knkusSl
# 3                               The Pains Of Growing  0JjJGeUbFqCRe4nKNVCAz9
# 4                                    In The Meantime  0O9ijXvoYpXDjqhaYZtA2X
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.486   0.773    6    -4.199     1       0.2450        0.1320
# 1         0.479   0.614    7    -7.001     1       0.3360        0.0130
# 2         0.539   0.524    4    -8.279     1       0.2360        0.0473
# 3         0.705   0.516    0    -5.770     1       0.1200        0.5830
# 4         0.718   0.721    4    -5.525     1       0.0429        0.0190
#
#    instrumentalness  liveness  valence    tempo  time_signature  \
# 0          0.000007    0.0840    0.439  120.145               4
# 1          0.000000    0.1620    0.406  171.930               4
# 2          0.000349    0.0806    0.729  174.047               3
# 3          0.000000    0.0780    0.422  115.740               4
# 4          0.000000    0.1440    0.963  108.070               4
#
#    artist_popularity  duration_minutes
# 0                 44          4.117700
# 1                 72          5.764517
# 2                 39          3.200450
# 3                 81          3.376667
# 4                 81          3.576900

# %% [markdown]
# ## Feature selection

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_24d7f_row0_col0, #T_24d7f_row1_col1, #T_24d7f_row2_col2, #T_24d7f_row3_col3, #T_24d7f_row4_col4, #T_24d7f_row5_col5, #T_24d7f_row6_col6, #T_24d7f_row7_col7, #T_24d7f_row8_col8, #T_24d7f_row9_col9, #T_24d7f_row10_col10, #T_24d7f_row11_col11, #T_24d7f_row12_col12, #T_24d7f_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_24d7f_row0_col1, #T_24d7f_row1_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_24d7f_row0_col2, #T_24d7f_row2_col0, #T_24d7f_row2_col8, #T_24d7f_row2_col13, #T_24d7f_row4_col13, #T_24d7f_row6_col13, #T_24d7f_row8_col2, #T_24d7f_row13_col2, #T_24d7f_row13_col4, #T_24d7f_row13_col6 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_24d7f_row0_col3, #T_24d7f_row3_col0, #T_24d7f_row3_col12, #T_24d7f_row12_col3 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_24d7f_row0_col4, #T_24d7f_row4_col0, #T_24d7f_row5_col7, #T_24d7f_row6_col10, #T_24d7f_row7_col5, #T_24d7f_row10_col6 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_24d7f_row0_col5, #T_24d7f_row5_col0, #T_24d7f_row10_col13, #T_24d7f_row11_col13, #T_24d7f_row13_col10, #T_24d7f_row13_col11 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_24d7f_row0_col6, #T_24d7f_row6_col0, #T_24d7f_row6_col9, #T_24d7f_row6_col11, #T_24d7f_row7_col9, #T_24d7f_row9_col6, #T_24d7f_row9_col7, #T_24d7f_row11_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_24d7f_row0_col7, #T_24d7f_row7_col0 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_24d7f_row0_col8, #T_24d7f_row4_col5, #T_24d7f_row5_col4, #T_24d7f_row8_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_24d7f_row0_col9, #T_24d7f_row9_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_24d7f_row0_col10, #T_24d7f_row10_col0 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_24d7f_row0_col11, #T_24d7f_row11_col0 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_24d7f_row0_col12, #T_24d7f_row5_col6, #T_24d7f_row6_col5, #T_24d7f_row11_col12, #T_24d7f_row12_col0, #T_24d7f_row12_col11 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_24d7f_row0_col13, #T_24d7f_row13_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_24d7f_row1_col2, #T_24d7f_row2_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_24d7f_row1_col3, #T_24d7f_row3_col1 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_24d7f_row1_col4, #T_24d7f_row4_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_24d7f_row1_col5, #T_24d7f_row2_col7, #T_24d7f_row4_col11, #T_24d7f_row5_col1, #T_24d7f_row7_col2, #T_24d7f_row9_col10, #T_24d7f_row9_col12, #T_24d7f_row10_col9, #T_24d7f_row10_col11, #T_24d7f_row11_col4, #T_24d7f_row11_col10, #T_24d7f_row12_col9 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_24d7f_row1_col6, #T_24d7f_row6_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_24d7f_row1_col7, #T_24d7f_row7_col1, #T_24d7f_row9_col13, #T_24d7f_row13_col9 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_24d7f_row1_col8, #T_24d7f_row6_col7, #T_24d7f_row7_col6, #T_24d7f_row8_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_24d7f_row1_col9, #T_24d7f_row9_col1 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_24d7f_row1_col10, #T_24d7f_row2_col9, #T_24d7f_row3_col10, #T_24d7f_row8_col11, #T_24d7f_row9_col2, #T_24d7f_row10_col1, #T_24d7f_row10_col3, #T_24d7f_row11_col8 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_24d7f_row1_col11, #T_24d7f_row11_col1 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_24d7f_row1_col12, #T_24d7f_row4_col10, #T_24d7f_row10_col4, #T_24d7f_row12_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_24d7f_row1_col13, #T_24d7f_row2_col10, #T_24d7f_row2_col11, #T_24d7f_row10_col2, #T_24d7f_row11_col2, #T_24d7f_row12_col13, #T_24d7f_row13_col1, #T_24d7f_row13_col12 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_24d7f_row2_col3, #T_24d7f_row3_col2, #T_24d7f_row8_col10, #T_24d7f_row10_col8 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_24d7f_row2_col4, #T_24d7f_row4_col2, #T_24d7f_row7_col12, #T_24d7f_row12_col7 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_24d7f_row2_col5, #T_24d7f_row5_col2, #T_24d7f_row5_col8, #T_24d7f_row8_col5 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_24d7f_row2_col6, #T_24d7f_row4_col9, #T_24d7f_row5_col13, #T_24d7f_row6_col2, #T_24d7f_row9_col4, #T_24d7f_row13_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_24d7f_row2_col12, #T_24d7f_row5_col11, #T_24d7f_row11_col5, #T_24d7f_row12_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_24d7f_row3_col4, #T_24d7f_row4_col3 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_24d7f_row3_col5, #T_24d7f_row4_col8, #T_24d7f_row5_col3, #T_24d7f_row8_col4 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_24d7f_row3_col6, #T_24d7f_row6_col3 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_24d7f_row3_col7, #T_24d7f_row7_col3 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_24d7f_row3_col8, #T_24d7f_row5_col9, #T_24d7f_row8_col3, #T_24d7f_row9_col5 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_24d7f_row3_col9, #T_24d7f_row9_col3 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_24d7f_row3_col11, #T_24d7f_row11_col3 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_24d7f_row3_col13, #T_24d7f_row6_col12, #T_24d7f_row12_col6, #T_24d7f_row13_col3 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_24d7f_row4_col6, #T_24d7f_row6_col4, #T_24d7f_row9_col11, #T_24d7f_row11_col9 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_24d7f_row4_col7, #T_24d7f_row7_col4, #T_24d7f_row8_col12, #T_24d7f_row12_col8 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_24d7f_row4_col12, #T_24d7f_row12_col4 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_24d7f_row5_col10, #T_24d7f_row10_col5 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_24d7f_row5_col12, #T_24d7f_row12_col5 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_24d7f_row6_col8, #T_24d7f_row8_col6 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_24d7f_row7_col8, #T_24d7f_row7_col10, #T_24d7f_row8_col7, #T_24d7f_row8_col13, #T_24d7f_row10_col7, #T_24d7f_row13_col8 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_24d7f_row7_col11, #T_24d7f_row11_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_24d7f_row7_col13, #T_24d7f_row10_col12, #T_24d7f_row12_col10, #T_24d7f_row13_col7 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_24d7f_row8_col9, #T_24d7f_row9_col8 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# </style>
# <table id="T_24d7f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >danceability</th>
#       <th class="col_heading level0 col1" >energy</th>
#       <th class="col_heading level0 col2" >key</th>
#       <th class="col_heading level0 col3" >loudness</th>
#       <th class="col_heading level0 col4" >mode</th>
#       <th class="col_heading level0 col5" >speechiness</th>
#       <th class="col_heading level0 col6" >acousticness</th>
#       <th class="col_heading level0 col7" >instrumentalness</th>
#       <th class="col_heading level0 col8" >liveness</th>
#       <th class="col_heading level0 col9" >valence</th>
#       <th class="col_heading level0 col10" >tempo</th>
#       <th class="col_heading level0 col11" >time_signature</th>
#       <th class="col_heading level0 col12" >artist_popularity</th>
#       <th class="col_heading level0 col13" >duration_minutes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24d7f_level0_row0" class="row_heading level0 row0" >danceability</th>
#       <td id="T_24d7f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_24d7f_row0_col1" class="data row0 col1" >0.127612</td>
#       <td id="T_24d7f_row0_col2" class="data row0 col2" >0.021153</td>
#       <td id="T_24d7f_row0_col3" class="data row0 col3" >0.176819</td>
#       <td id="T_24d7f_row0_col4" class="data row0 col4" >-0.090161</td>
#       <td id="T_24d7f_row0_col5" class="data row0 col5" >0.075420</td>
#       <td id="T_24

# %% [markdown]
# > In the project ["Unsupervised Anomaly Detection on Spotify data 🎵: K-Means vs Local Outlier Factor,"](https://github.com/isaacarroyov/spotify_anomalies_kmeans-lof) I chose 6 variables that weren't highly correlated. For this data visualization I'm going to use features that are highly correlated. Why? PCA minimizes the lost of information and highly correlated features have a lot of information.

# %%
df_pca = df[['energy', 'loudness', 'acousticness', 'valence']]
df_pca.head()
# Out:
#    energy  loudness  acousticness  valence
# 0   0.773    -4.199        0.1320    0.439
# 1   0.614    -7.001        0.0130    0.406
# 2   0.524    -8.279        0.0473    0.729
# 3   0.516    -5.770        0.5830    0.422
# 4   0.721    -5.525        0.0190    0.963

# %% [markdown]
# ## Dimensionality Reduction: Principal Component Analysis

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# > I'm going to reduce the n-dimensional dataset into a two-dimensional one.

# %%
pca = PCA(n_components = 2)

# Create new features
pca.fit(df_pca.values)
df[['z1','z2']] = pca.transform(df_pca.values)

# Percentage of variance explained by each of the components
z1_explained_variance, z2_explained_variance = pca.explained_variance_ratio_

# %% [markdown]
# ## Create visualization

# %% [markdown]
# > This data visualization has the only porpouse to showcase the entire distribution of the dataset in a eye pleasing way. The variables selected to add colour and size were chosen to present it aesthetically.

# %%
top_10_artists = df.groupby('artist').count().reset_index()[['artist','name']]\
                 .sort_values("name", ascending=False)\
                 .rename(columns={"name":"numbers_songs"}).head(10)
list_top_10_artist = top_10_artists.artist.values.tolist()

# %%
def label_top_ten_artist(artist, list_top_ten_artists):
    if artist in list_top_ten_artists:
        return artist
    else: return "Other"

df['artist_top_ten'] = df['artist'].apply(label_top_ten_artist, args=(list_top_10_artist,))

# %%
# Create layers of information
chart = alt.Chart(data=df).mark_circle()\
        .encode(x= alt.X(shorthand='z1:Q', axis= alt.Axis(title=[f'Z₁ (explains {round(z1_explained_variance * 100,1)}% ','of the variance)'])),
                y= alt.Y(shorthand='z2:Q', axis= alt.Axis(title=[f'Z₂ (explains {round(z2_explained_variance * 100,1)}% ','of the variance)'])),
                opacity = alt.Opacity(shorthand='valence:Q',
                                      scale= alt.Scale(range=[0.2,0.9]),
                                      legend= alt.Legend(orient='none', direction='horizontal', title="Song's Positivity",legendX=450,legendY=-100)),
                size= alt.Size(shorthand='acousticness:Q',scale= alt.Scale(range=[50,550]),
                               legend= alt.Legend(orient='none', direction='horizontal',title='Acousticness',legendX= 450, legendY=-45)),
                color= alt.Color(shorthand='artist_top_ten',legend= alt.Legend(orient='none', title="Top 10 artists", columns=3,legendX=-160, legendY=-100),
                                 scale = alt.Scale(domain=list_top_10_artist + ["Other"],
                                                   range = ['#F94144','#F3722C','#F8961E','#F9844A','#F9C74F','#90BE6D',
                                                            '#43AA8B','#7AB8B6','#8CA5BA','#ADD8EB','#70E5FF']
                                                  )
                                
                                ),
                tooltip = [alt.Tooltip(shorthand='name', title= "Song"), alt.Tooltip(shorthand='artist', title= "Artist"),
                           alt.Tooltip(shorthand='energy', title= "Energy"), alt.Tooltip(shorthand='loudness', title= "Loudness"),
                           alt.Tooltip(shorthand='acousticness', title= "Acousticness"), alt.Tooltip(shorthand='valence', title= "Song's Positivity")]
        )
# Configure plot
chart = chart.properties(width=1080*0.8, height=1080*0.6, 
                         title = alt.TitleParams(text=["Visualizing Spotify: The 5, 4, 3, 2 and 1"],
                                                 anchor="start", offset=30,
                                                 fontSize=45,
                                                 subtitle= ["5 years of music: All the songs I listened to during my time in college (2016 - 2021)",
                                                            "4 spotify audio features: Energy, Loudness, Acousticness and Song's Positivity",
                                                            "3 encodings: Song's positivity (opacity), Acousticness (size) and whether the artist of the song is part of",
                                                            "the top 10 or not (colour)",
                                                            "2-dimensional representation: Principal Component Analysis (PCA) was used for",
                                                            "Dimensionality Reduction",
                                                            "1 user: Me"," ", "Visualization by Isaac Arroyo (@unisaacarroyov)"], 
                                                 subtitleFontSize= 25, subtitlePadding=10,
                                                 color = 'white', subtitleColor='#white'
                            
                                                )
)\
.configure(font='Palatino', background='#001219',)\
.configure_view(stroke=None)\
.configure_legend(titleFontSize=23, labelFontSize=20, titleColor='white', labelColor='white',
                  symbolFillColor='white', symbolStrokeColor='white', symbolStrokeWidth=0.5 )\
.configure_axisY(titleAngle=0, titlePadding=80)\
.configure_axisX(titleX=200)\
.configure_axis(grid=False, ticks=False, labels=False, domain=False, titleFontSize = 30, titleColor='white')

chart = chart.interactive()
chart
# Out:
# alt.Chart(...)

# %%
import datapane as dp

dp.Report(dp.Plot(chart)).upload(name="Visualizing Spotify: The 5, 4, 3, 2 and 1", visibility= dp.Visibility.PORTFOLIO)
# Out:
# Uploading report and associated data - *please wait...*
# Your report only contains a single element - did you know you can include additional plots, tables and text in a single report? More info <a href='https://docs.datapane.com/reports/blocks/layout-pages-and-selects' target='_blank'>here</a>
# Report successfully uploaded. View and share your report <a href='https://datapane.com/u/unisaacarroyov/reports/E7Pwzy3/visualizing-spotify-the-5-4-3-2-and-1/' target='_blank'>here</a>, or edit your report <a href='https://datapane.com/u/unisaacarroyov/reports/E7Pwzy3/visualizing-spotify-the-5-4-3-2-and-1/edit/' target='_blank'>here</a>.
